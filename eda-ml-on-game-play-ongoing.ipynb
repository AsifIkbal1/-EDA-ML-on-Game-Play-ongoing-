# %% [markdown]
# <div style="color:#6F2648;margin:0;font-size:40px;font-family:Georgia;text-align:center;display:fill;border-radius:5px;overflow:hidden;font-weight:600;"> From Game Play <br>Predict Student Performance</div>
#
# <h5 style="text-align: center; font-family: Verdana; font-size: 12px; font-style: normal; font-weight: bold; text-decoration: None; text-transform: none; letter-spacing: 1px; color: #254E58; background-color: #ffffff;">CREATED BY: NGUYEN THI CAM LAI</h5>
#
# <br>
# <p style="text-align: center;">
# <img src="https://raw.githubusercontent.com/ntclai/PictureForMyProject/main/game2.png" style='width: 500px; height: 500px;'>
# </p>

# %% [markdown]
# <a id="top"></a>
# # <div style="padding:20px;color:white;margin:0;font-size:35px;font-family:Georgia;text-align:left;display:fill;border-radius:5px;background-color:#254E58;overflow:hidden"><b>Table of content</b></div>
#
# <div style="background-color:aliceblue; padding:30px; font-size:15px;color:#034914">
#
# * [1. Introduction](#1)
#     - [Problem statement](#1.1)
#     - [Data description](#1.2)
#
# * [2. Import libraries](#2)
#
# * [3. Basic Exploration](#3)
#     - [Read dataset](#3.1)
#     - [Some information](#3.2)
#     - [Data visualization](#3.3)
# * [4. Machine Learning model](#4)
#
# * [5 Conclusion](#5)
#
# * [6 Author Message](#6)

# %% [markdown]
# <a id="1"></a>
# # <div style="padding:20px;color:white;margin:0;font-size:35px;font-family:Georgia;text-align:left;display:fill;border-radius:5px;background-color:#254E58;overflow:hidden"><b>Introduction</b></div>

# %% [markdown]
# <a id="1.2"></a>
# <h2 style="font-family: Verdana; font-size: 25px; font-style: normal; font-weight: normal; text-decoration: none; text-transform: none; letter-spacing: 2px; color: #155D07; background-color: #ffffff;"><b>Problem</b> statement

# %% [markdown]
# <span style="font-size:14px; font-family:Verdana;"> Learning is meant to be fun, which is where game-based learning comes in. This educational approach allows students to engage with educational content inside a game framework, making it enjoyable and dynamic. Although game-based learning is being used in a growing number of educational settings, there are still a limited number of open datasets available to apply data science and learning analytic principles to improve game-based learning.<br>
# Most game-based learning platforms do not sufficiently make use of knowledge tracing to support individual students. Knowledge tracing methods have been developed and studied in the context of online learning environments and intelligent tutoring systems. But there has been less focus on knowledge tracing in educational games.<br>
# Competition host Field Day Lab is a publicly-funded research lab at the Wisconsin Center for Educational Research. They design games for many subjects and age groups that bring contemporary research to the public, making use of the game data to understand how people learn. Field Day Lab's commitment to accessibility ensures all of its games are free and available to anyone. The lab also partners with nonprofits like The Learning Agency Lab, which is focused on developing science of learning-based tools and programs for the social good.<br>
# If successful, you'll enable game developers to improve educational games and further support the educators who use these games with dashboards and analytic tools. In turn, we might see broader support for game-based learning platforms.
# </span>

# %% [markdown]
# <center> <a href="#top" role="button" aria-pressed="true" >⬆️Back to Table of Contents ⬆️</a>

# %% [markdown]
# <a id="1.2"></a>
# <h2 style="font-family: Verdana; font-size: 25px; font-style: normal; font-weight: normal; text-decoration: none; text-transform: none; letter-spacing: 2px; color: #155D07; background-color: #ffffff;"><b>Data</b> description

# %% [markdown]
# <span style="font-size:14px; font-family:Verdana;"> This competition uses the Kaggle's time series API. Test data will be delivered in groupings that do not allow access to future data. The objective of this competition is to use time series data generated by an online educational game to determine whether players will answer questions correctly. There are three question checkpoints (level 4, level 12, and level 22), each with a number of questions. At each checkpoint, you will have access to all previous test data for that section.</span>
#
# |No  | Columns name |  Meaning |
# |:---| :---         |:---      |
# | 1  | <font color="#254441"> session_id </font>  |  the ID of the session the event took place in |
# | 2  | <font color="#254441"> index </font>  |  the index of the event for the session |
# | 3  | <font color="#254441"> elapsed_time </font>  |  how much time has passed (in milliseconds) between the start of the session <br>and when the event was recorded  |
# | 4  | <font color="#254441"> event_name </font>  | the name of the event type  |
# | 5  | <font color="#254441"> name </font>  |  the event name (e.g. identifies whether a notebook_click is is opening<br> or closing the notebook) |
# | 6  | <font color="#254441"> level </font>  |  what level of the game the event occurred in (0 to 22)  |
# | 7  | <font color="#254441"> page </font>  |   the page number of the event (only for notebook-related events) |
# | 8  | <font color="#254441"> room_coor_x </font>  | the coordinates of the click in reference to the in-game room (only for click events)  |
# | 9  | <font color="#254441"> room_coor_y </font>  |  the coordinates of the click in reference to the in-game room (only for click events) |
# | 10  | <font color="#254441"> screen_coor_x </font>  | the coordinates of the click in reference to the player’s screen (only for click events)  |
# | 11  | <font color="#254441"> screen_coor_y </font>  |  the coordinates of the click in reference to the player’s screen (only for click events) |
# | 12  | <font color="#254441"> hover_duration </font>  |  how long (in milliseconds) the hover happened for (only for hover events) |
# | 13  | <font color="#254441"> text </font>  | the text the player sees during this event  |
# | 14  | <font color="#254441"> fqid  </font>  | the fully qualified ID of the event  |
# | 15  | <font color="#254441"> room_fqid  </font>  | the fully qualified ID of the room the event took place in  |
# | 16 | <font color="#254441">  text_fqid </font>  |  the fully qualified ID of the  |
# | 17  | <font color="#254441">  fullscreen  </font>  |  whether the player is in fullscreen mode |
# | 18  | <font color="#254441">  hq  </font>  |  whether the game is in high-quality |
# | 19  | <font color="#254441">  music </font>  |   whether the game music is on or off |
# | 20  | <font color="#254441"> level_group  </font>  | which group of levels - and group of questions - this row belongs to (0-4, 5-12, 13-22)  |

# %% [markdown]
# <center> <a href="#top" role="button" aria-pressed="true" >⬆️Back to Table of Contents ⬆️</a>

# %% [markdown]
# <a id="2"></a>
# # <div style="padding:20px;color:white;margin:0;font-size:35px;font-family:Georgia;text-align:left;display:fill;border-radius:5px;background-color:#254E58;overflow:hidden"><b>Import libraries</b></div>

# %%
import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno
import pandas as pd
import numpy as np
import matplotlib
from plotly.subplots import make_subplots
import plotly.graph_objects as go
theme_colors = ['#901272', '#94A832', '#6C7CD3', '#F16262', '#4C5760']
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# <center> <a href="#top" role="button" aria-pressed="true" >⬆️Back to Table of Contents ⬆️</a>

# %% [markdown]
# <a id="3"></a>
# # <div style="padding:20px;color:white;margin:0;font-size:35px;font-family:Georgia;text-align:left;display:fill;border-radius:5px;background-color:#254E58;overflow:hidden"><b>Basic exploration </b></div>

# %% [markdown]
# <a id="3.1"></a>
# <h2 style="font-family: Verdana; font-size: 25px; font-style: normal; font-weight: normal; text-decoration: none; text-transform: none; letter-spacing: 2px; color: #155D07; background-color: #ffffff;"><b>Read</b> dataset </h2>

# %%
def read_dataset():
    train = pd.read_csv("/kaggle/input/predict-student-performance-from-game-play/train.csv")
    print('Train data imported successfully!')
    train_labels = pd.read_csv("/kaggle/input/predict-student-performance-from-game-play/train_labels.csv")
    print('Train labels data imported successfully!')
    test=pd.read_csv("/kaggle/input/predict-student-performance-from-game-play/test.csv")
    print('Test data imported sucessfully!')
    return train, train_labels, test

# %%
raw_train_df, raw_train_labels_df, raw_test_df=read_dataset()

# %% [markdown]
# <a id="3.2"></a>
# <h2 style="font-family: Verdana; font-size: 25px; font-style: normal; font-weight: normal; text-decoration: none; text-transform: none; letter-spacing: 2px; color: #155D07; background-color: #ffffff;"><b>Some</b> information </h2>

# %% [markdown]
# > <span style='font-size:15px; font-family:Verdana;color: #254E58;'><b>Display data content</b></span>

# %%
raw_train_df.head()
print("train.csv:")

# %%
raw_train_labels_df.head()
print("train_labels.csv")

# %%
raw_test_df.head()
print("test.csv")

# %% [markdown]
# <center> <a href="#top" role="button" aria-pressed="true" >⬆️Back to Table of Contents ⬆️</a>

# %% [markdown]
# > <span style='font-size:15px; font-family:Verdana;color: #254E58;'><b>
# Number of rows, number of columns</b></span>

# %%
train_num_rows, train_num_cols = raw_train_df.shape
print(f'Train data \nNumber of rows : {train_num_rows}\nNumber of columns: {train_num_cols}')

# %%
test_num_rows, test_num_cols = raw_test_df.shape
print(f'Train data \nNumber of rows : {test_num_rows}\nNumber of columns: {test_num_cols}')

# %% [markdown]
# <center> <a href="#top" role="button" aria-pressed="true" >⬆️Back to Table of Contents ⬆️</a>

# %% [markdown]
# > <span style='font-size:15px; font-family:Verdana;color: #254E58;'><b>Basic info</b></span>

# %%
print("Info of train data:")
print(raw_train_df.info())

# %%
print("Info of test data:")
print(raw_test_df.info())

# %%
print("Info of train labels data:")
print(raw_train_labels_df.info())

# %% [markdown]
# <center> <a href="#top" role="button" aria-pressed="true" >⬆️Back to Table of Contents ⬆️</a>

# %% [markdown]
# > <span style='font-size:15px; font-family:Verdana;color: #254E58;'><b>Count null/nan values</b></span>

# %%
raw_train_df.isna().sum()
print("nan of train.csv:")

# %%
raw_train_df.isnull().sum()
print("null of train.csv")

# %% [markdown]
# <center> <a href="#top" role="button" aria-pressed="true" >⬆️Back to Table of Contents ⬆️</a>

# %% [markdown]
# <a id="3.3"></a>
# <h2 style="font-family: Verdana; font-size: 25px; font-style: normal; font-weight: normal; text-decoration: none; text-transform: none; letter-spacing: 2px; color: #155D07; background-color: #ffffff;"><b>Data</b> visualization </h2>

# %% [markdown]
# > <span style='font-size:15px; font-family:Verdana;color: #254E58;'><b> Event_name - The name of the event typeㅤ</b></span>

# %%
print(f'\n There are {len(raw_train_df["event_name"].unique())} name event enlisted here.\n')
name_event_unique=np.unique(raw_train_df['event_name'])
name_event_unique=pd.DataFrame(name_event_unique, columns=['event_name'])
name_event_unique.T.style.set_properties(**{"background-color": "#254441","color":"#e9c46a","border": "1.5px solid black"})

# %%
event_name_df=raw_train_df.groupby(['event_name'])['event_name'].count().sort_values()
sns.set(rc={"axes.facecolor":"#F2EAC5","figure.facecolor":"#F2EAC5"})
palette = ["#11264e","#00507A","#026e90","#008b99","#6faea4","#fcdcb0","#FEE08B","#faa96e","#f36b3b","#ef3f28","#CC0028"]
plt.subplots(figsize=(20, 10))
p=sns.barplot(event_name_df.values,event_name_df.index,palette=palette, saturation=1, edgecolor = "#1c1c1c", linewidth = 4)
p.axes.set_title("\nName of the event that took place\n",fontsize=25)
p.axes.set_xlabel("Count",fontsize=20)
p.axes.set_ylabel("Name event",fontsize=20)
p.axes.set_xticklabels(p.get_xticklabels(),rotation = 90)
for container in p.containers:
    p.bar_label(container,label_type="edge",padding=6,size=20,color="black",rotation=0,
    bbox={"boxstyle": "round", "pad": 0.4, "facecolor": "orange", "edgecolor": "#1c1c1c", "linewidth" : 1.5, "alpha": 1})

sns.despine(left=True, bottom=True)
plt.show()

# %% [markdown]
# <center> <a href="#top" role="button" aria-pressed="true" >⬆️Back to Table of Contents ⬆️</a>

# %% [markdown]
# > <span style='font-size:15px; font-family:Verdana;color: #254E58;'><b>ㅤHow many descriptive definitions are there for an event? (columns: name) </b></span>

# %%
print(f'\n There are {len(raw_train_df["name"].unique())} name enlisted here.\n')
name_unique=np.unique(raw_train_df['name'])
name_unique=pd.DataFrame(name_unique, columns=['name'])
name_unique.T.style.set_properties(**{"background-color": "#254441","color":"#e9c46a","border": "1.5px solid black"})

# %%
temp=raw_train_df.groupby(["event_name","name"])["event_name"].count()

d = {'name': ['basic'], 'count': [temp[0]]}
checkpoint = pd.DataFrame(data=d)

d = {'name': ['basic'], 'count': [temp[1]]}
cutscene_click  = pd.DataFrame(data=d)

d = {'name': ['basic','close','undefined'], 'count': [temp[2],temp[3],temp[4]]}
map_click = pd.DataFrame(data=d)

d = {'name': ['basic'], 'count': [temp[5]]}
map_hover  = pd.DataFrame(data=d)

d = {'name': ['undenfined'], 'count': [temp[6]]}
navigate_click = pd.DataFrame(data=d)

d = {'name': ['basic','close','next','open','prev'], 'count': [temp[7], temp[8], temp[9], temp[10], temp[11]]}
notebook_click  = pd.DataFrame(data=d)

d = {'name': ['basic'], 'count': [temp[12]]}
notification_click = pd.DataFrame(data=d)

d = {'name': ['basic','close'], 'count': [temp[13], temp[14]]}
object_click = pd.DataFrame(data=d)

d = {'name': ['basic','undefined '], 'count': [temp[15], temp[16]]}
object_hover = pd.DataFrame(data=d)

d = {'name': ['basic'], 'count': [temp[17]]}
observation_click = pd.DataFrame(data=d)

d = {'name': ['basic'], 'count': [temp[18]]}
person_click = pd.DataFrame(data=d)

# %%
cutscene_click

# %%
fig = make_subplots(rows=6, cols=2,
                    specs=[[{'type':'domain'}, {'type':'domain'}],
                           [{'type':'domain'}, {'type':'domain'}],
                           [{'type':'domain'}, {'type':'domain'}],
                           [{'type':'domain'}, {'type':'domain'}],
                           [{'type':'domain'}, {'type':'domain'}],
                           [{'type':'domain'}, {'type':'domain'}]
                          ])
fig.add_trace(
    go.Pie(
        labels=checkpoint['name'],
        values=checkpoint['count'],
        hole=.7,
        title='checkpoint',
        titlefont={'color':None, 'size': 15},
        ),
    row=1,col=1
    )

fig.add_trace(
    go.Pie(
        labels=cutscene_click['name'],
        values=cutscene_click['count'],
        hole=.7,
        title='cutscene_click',
        titlefont={'color':None, 'size': 15},
        ),
    row=1,col=2
    )

fig.add_trace(
    go.Pie(
        labels=map_click['name'],
        values=map_click['count'],
        hole=.7,
        title='map_click',
        titlefont={'color':None, 'size': 15},
        ),
    row=2,col=1
    )


fig.add_trace(
    go.Pie(
        labels=map_hover['name'],
        values=map_hover['count'],
        hole=.7,
        title='map_hover',
        titlefont={'color':None, 'size': 15},
        ),
    row=2,col=2
    )

fig.add_trace(
    go.Pie(
        labels=navigate_click['name'],
        values=navigate_click['count'],
        hole=.7,
        title='navigate_click',
        titlefont={'color':None, 'size': 15},
        ),
    row=3,col=1
    )

fig.add_trace(
    go.Pie(
        labels=notebook_click ['name'],
        values=notebook_click ['count'],
        hole=.7,
        title='notebook_click ',
        titlefont={'color':None, 'size': 15},
        ),
    row=3,col=2
    )

fig.add_trace(
    go.Pie(
        labels=notification_click['name'],
        values=notification_click['count'],
        hole=.7,
        title='notification_click',
        titlefont={'color':None, 'size': 15},
        ),
    row=4,col=1
    )

fig.add_trace(
    go.Pie(
        labels=object_click['name'],
        values=object_click['count'],
        hole=.7,
        title='object_click',
        titlefont={'color':None, 'size': 15},
        ),
    row=4,col=2
    )

fig.add_trace(
    go.Pie(
        labels=object_hover['name'],
        values=object_hover['count'],
        hole=.7,
        title='object_hover',
        titlefont={'color':None, 'size': 15},
        ),
    row=5,col=1
    )

fig.add_trace(
    go.Pie(
        labels=observation_click['name'],
        values=observation_click['count'],
        hole=.7,
        title='observation_click',
        titlefont={'color':None, 'size': 15},
        ),
    row=5,col=2
    )

fig.add_trace(
    go.Pie(
        labels=person_click['name'],
        values=person_click['count'],
        hole=.7,
        title='person_click',
        titlefont={'color':None, 'size': 15},
        ),
    row=6,col=1
    )

fig.update_traces(
    hoverinfo='label+value',
    textinfo='label+percent',
    textfont_size=20,
    marker=dict(
        colors=theme_colors,
        line=dict(color='#EEEEEE',
                  width=2)
        )
    )

fig.layout.update(title="<b> How many descriptive definitions are there for an event?<b>",
                  titlefont={'color':None, 'size': 20, 'family': 'Courier New'},
                  showlegend=False, 
                  height=1700, 
                  width=600,
                  template='plotly_dark',
                  title_x=0.2
                  )
fig.show()

# %% [markdown]
# <center> <a href="#top" role="button" aria-pressed="true" >⬆️Back to Table of Contents ⬆️</a>

# %% [markdown]
# > <span style='font-size:15px; font-family:Verdana;color: #254E58;'><b>ㅤThe level distribution of events </b></span>

# %%
level=pd.DataFrame({'count': raw_train_df.groupby(["event_name","level"]).size()}).reset_index()
checkpoint=level.loc[level['event_name']=='checkpoint']
observation_click=level.loc[level['event_name']=='observation_click']
map_click =level.loc[level['event_name']=='map_click']
notebook_click=level.loc[level['event_name']=='notebook_click']
notification_click=level.loc[level['event_name']=='notification_click']
map_hover=level.loc[level['event_name']=='map_hover']
object_hover=level.loc[level['event_name']=='object_hover']
object_click=level.loc[level['event_name']=='object_click']
cutscene_click=level.loc[level['event_name']=='cutscene_click']
person_click=level.loc[level['event_name']=='person_click']
navigate_click=level.loc[level['event_name']=='navigate_click']

checkpoint['level']=checkpoint['level'].astype(str)
fig=px.bar(y=checkpoint['count'],
          x=checkpoint['level'],
          color=checkpoint['level'],
          color_discrete_sequence=px.colors.sequential.deep,
          text=checkpoint['count'],
          title="checkpoint",
          template="plotly_dark")
fig.update_layout(xaxis_title="Level",
                 yaxis_title="Count",
                 font=dict(size=17,family="Franklin Gpthic"))
fig.show()

observation_click['level']=observation_click['level'].astype(str)
fig=px.bar(y=observation_click['count'],
          x=observation_click['level'],
          color=observation_click['level'],
          color_discrete_sequence=px.colors.sequential.deep,
          text=observation_click['count'],
          title="observation_click",
          template="plotly_dark")
fig.update_layout(xaxis_title="Level",
                 yaxis_title="Count",
                 font=dict(size=17,family="Franklin Gpthic"))
fig.show()

map_click['level']=map_click['level'].astype(str)
fig=px.bar(y=map_click['count'],
          x=map_click['level'],
          color=map_click['level'],
          color_discrete_sequence=px.colors.sequential.deep,
          text=map_click['count'],
          title="map_click",
          template="plotly_dark")
fig.update_layout(xaxis_title="Level",
                 yaxis_title="Count",
                 font=dict(size=17,family="Franklin Gpthic"))
fig.show()

notebook_click['level']=notebook_click['level'].astype(str)
fig=px.bar(y=notebook_click['count'],
          x=notebook_click['level'],
          color=notebook_click['level'],
          color_discrete_sequence=px.colors.sequential.deep,
          text=notebook_click['count'],
          title="notebook_click",
          template="plotly_dark")
fig.update_layout(xaxis_title="Level",
                 yaxis_title="Count",
                 font=dict(size=17,family="Franklin Gpthic"))
fig.show()

notification_click['level']=notification_click['level'].astype(str)
fig=px.bar(y=notification_click['count'],
          x=notification_click['level'],
          color=notification_click['level'],
          color_discrete_sequence=px.colors.sequential.deep,
          text=notification_click['count'],
          title="notification_click",
          template="plotly_dark")
fig.update_layout(xaxis_title="Level",
                 yaxis_title="Count",
                 font=dict(size=17,family="Franklin Gpthic"))
fig.show()

map_hover['level']=map_hover['level'].astype(str)
fig=px.bar(y=map_hover['count'],
          x=map_hover['level'],
          color=map_hover['level'],
          color_discrete_sequence=px.colors.sequential.deep,
          text=map_hover['count'],
          title="map_hover",
          template="plotly_dark")
fig.update_layout(xaxis_title="Level",
                 yaxis_title="Count",
                 font=dict(size=17,family="Franklin Gpthic"))
fig.show()

object_hover['level']=object_hover['level'].astype(str)
fig=px.bar(y=object_hover['count'],
          x=object_hover['level'],
          color=object_hover['level'],
          color_discrete_sequence=px.colors.sequential.deep,
          text=object_hover['count'],
          title="object_hover",
          template="plotly_dark")
fig.update_layout(xaxis_title="Level",
                 yaxis_title="Count",
                 font=dict(size=17,family="Franklin Gpthic"))
fig.show()

object_click['level']=object_click['level'].astype(str)
fig=px.bar(y=object_click['count'],
          x=object_click['level'],
          color=object_click['level'],
          color_discrete_sequence=px.colors.sequential.deep,
          text=object_click['count'],
          title="object_click",
          template="plotly_dark")
fig.update_layout(xaxis_title="Level",
                 yaxis_title="Count",
                 font=dict(size=17,family="Franklin Gpthic"))
fig.show()

cutscene_click['level']=cutscene_click['level'].astype(str)
fig=px.bar(y=cutscene_click['count'],
          x=cutscene_click['level'],
          color=cutscene_click['level'],
          color_discrete_sequence=px.colors.sequential.deep,
          text=cutscene_click['count'],
          title="cutscene_click",
          template="plotly_dark")
fig.update_layout(xaxis_title="Level",
                 yaxis_title="Count",
                 font=dict(size=17,family="Franklin Gpthic"))
fig.show()

person_click['level']=person_click['level'].astype(str)
fig=px.bar(y=person_click['count'],
          x=person_click['level'],
          color=person_click['level'],
          color_discrete_sequence=px.colors.sequential.deep,
          text=person_click['count'],
          title="person_click",
          template="plotly_dark")
fig.update_layout(xaxis_title="Level",
                 yaxis_title="Count",
                 font=dict(size=17,family="Franklin Gpthic"))
fig.show()

navigate_click['level']=navigate_click['level'].astype(str)
fig=px.bar(y=navigate_click['count'],
          x=navigate_click['level'],
          color=navigate_click['level'],
          color_discrete_sequence=px.colors.sequential.deep,
          text=navigate_click['count'],
          title="navigate_click",
          template="plotly_dark")
fig.update_layout(xaxis_title="Level",
                 yaxis_title="Count",
                 font=dict(size=17,family="Franklin Gpthic"))
fig.show()

# %% [markdown]
# > <span style='font-size:15px; font-family:Verdana;color: #254E58;'><b>ㅤLevel and Elapsed_time </b></span>

# %%
level_w_elapsed_time = pd.DataFrame(raw_train_df.groupby("level").agg({"elapsed_time": "mean"}))
level_w_elapsed_time = level_w_elapsed_time.reset_index(drop=False)
level_w_elapsed_time.columns = ["level", "elapsed_time"]
level_w_elapsed_time = level_w_elapsed_time.sort_values(by="level", ascending=True)

x, y = level_w_elapsed_time["level"].values, level_w_elapsed_time["elapsed_time"]
min_x, max_x = np.min(x), np.max(x)

figure = plt.figure(figsize=(20, 7))
axis = figure.add_subplot()
axis.grid(axis="both", zorder=0)
sns.lineplot(x=x, y=y, color="#fff", linewidth=2, alpha=1.0, ax=axis, zorder=2)
axis.yaxis.set_tick_params(labelsize=14)
axis.set_ylabel("elapsed_time", fontsize=15)
axis.set_xlabel("level", fontsize=15)
axis.xaxis.set_tick_params(labelsize=12)
axis.yaxis.set_tick_params(labelsize=12)
axis.fill_between(x, y, color="#2F718C", edgecolor="#fff", alpha=1.0, zorder=2)
axis.set_xticks(range(min_x, max_x+1, 1))
axis.set_xlim(min_x, max_x)
axis.set_ylim(0.0)
figure.show()

# %% [markdown]
# <center> <a href="#top" role="button" aria-pressed="true" >⬆️Back to Table of Contents ⬆️</a>

# %% [markdown]
# > <span style='font-size:15px; font-family:Verdana;color: #254E58;'><b>Page </b></span>

# %%
page = raw_train_df['page'].value_counts()
fig = px.pie(values=page.values, 
             names=page.index, 
             color_discrete_sequence=px.colors.sequential.PuBu,
             title= 'Page distribution',template='plotly_dark')
fig.update_traces(textinfo='label+percent+value', textfont_size=14,
                  marker=dict(line=dict(color='#100000', width=0.2)))

fig.data[0].marker.line.width = 2
fig.data[0].marker.line.color='gray'
fig.update_layout(
    font=dict(size=20,family="Franklin Gothic"))
fig.show()

# %% [markdown]
# <center> <a href="#top" role="button" aria-pressed="true" >⬆️Back to Table of Contents ⬆️</a>

# %% [markdown]
# > <span style='font-size:15px; font-family:Verdana;color: #254E58;'><b>Level_group </b></span>

# %%
level_group = raw_train_df['level_group'].value_counts()
fig = px.pie(values=level_group.values,
             names=level_group.index,
             color_discrete_sequence=px.colors.sequential.PuBu,
             title= 'Level group distribution',template='plotly_dark')

fig.update_traces(textinfo='label+percent+value', textfont_size=14,
                  marker=dict(line=dict(color='#100000', width=0.2)))

fig.data[0].marker.line.width = 2
fig.data[0].marker.line.color='gray'
fig.update_layout(
    font=dict(size=20,family="Franklin Gothic"))
fig.show()

# %% [markdown]
# <center> <a href="#top" role="button" aria-pressed="true" >⬆️Back to Table of Contents ⬆️</a>

# %% [markdown]
# <a id="4"></a>
# # <div style="padding:20px;color:white;margin:0;font-size:35px;font-family:Georgia;text-align:left;display:fill;border-radius:5px;background-color:#254E58;overflow:hidden"><b> Machine Learning model</b></div>

# %% [markdown]
# on going!

# %% [markdown]
# <a id="5"></a>
# # <div style="padding:20px;color:white;margin:0;font-size:35px;font-family:Georgia;text-align:left;display:fill;border-radius:5px;background-color:#254E58;overflow:hidden"><b> Conclusion</b></div>

# %% [markdown]
# on going!

# %% [markdown]
# <a id="6"></a>
# # <div style="padding:20px;color:white;margin:0;font-size:35px;font-family:Georgia;text-align:left;display:fill;border-radius:5px;background-color:#254E58;overflow:hidden"><b> Author Message</b></div>

# %% [markdown]
# <div style="border-radius:10px;border:#034914 solid;padding: 15px;background-color:aliceblue;font-size:90%;text-align:left">
#
# <h4><b>Author :</b> Nguyen Thi Cam Lai </h4>
#
# <h4> <b>Some information:</b> </h4>
#
# <b>👉Read more project :</b> https://www.kaggle.com/nguyenthicamlai <br>
# <b>👉Shoot me mails :</b> lainguyen130302@gmail.com<br>
# <b>👉Connect on LinkedIn :</b> https://www.linkedin.com/in/ntclaii/ <br>
# <b>👉Explore Github :</b> https://github.com/ntclai <br>
#
#
# <center> <strong> If you liked this Notebook, please do upvote. </strong>
#
# <center> <strong> If you have any questions, feel free to comment! </strong>
#
# <center> <strong> ✨Best Wishes✨ </strong>

# %% [markdown]
# <center> <img src="https://raw.githubusercontent.com/ntclai/PictureForMyProject/main/87481-of-thanks-letter-text-logo-calligraphy-drawing%20(1).png" style='width: 600px; height: 300px;'>

# %% [markdown]
# <center> <a href="#top" role="button" aria-pressed="true" >⬆️Back to Table of Contents ⬆️</a>
